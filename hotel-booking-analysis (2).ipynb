# %% [markdown]
#  Project: Hotel Booking Analsis
#
# Dataset : hotel-bookinng
#
# Introduction 👋 Hello, everyone! My name is Parag Narendra Fartode, and I'm delighted to introduce myself to you. I am a Junior Data Analyst passionate about leveraging data to derive meaningful insights and drive impactful decisions. With a keen interest in exploring the realms of data science, I actively engage in various projects and share my learnings through platforms like Kaggle.¶
#
# About Me 🔍 As a Junior Data Scientist, I immerse myself in the world of data, constantly seeking innovative ways to analyze, interpret, and visualize information to solve real-world problems. My journey in data science is fueled by a curiosity to unravel patterns, discover trends, and uncover hidden insights within complex datasets.
#
# My Work 📊 I regularly upload my data analysis notebooks and projects on Kaggle, where I showcase my skills in data manipulation, exploratory data analysis (EDA), machine learning, and more. Through these notebooks, I aim to contribute to the data science community by sharing methodologies, code snippets, and insights gained from my projects.
#
# Passion & Goals 💡 My passion for data science extends beyond technical skills. I am dedicated to continuous learning and improvement, staying updated with the latest advancements in the field. My ultimate goal is to harness the power of data to make a positive impact on society, whether it's through enhancing business strategies, addressing societal challenges, or driving innovation in various domains.
#
# Let's Connect 🤝 I am always open to collaboration, knowledge sharing, and networking opportunities. Feel free to connect with me on Kaggle or other professional platforms to discuss data science, share ideas, or explore potential collaborations

# %%
# importing librarys
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# importing data
df = pd.read_csv('/kaggle/input/hotel-bookings/hotel_bookings final.csv',encoding='unicode_escape')

# %%
#show data
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  agent  company  \
# 0                        0                     0       2  ...    NaN      NaN
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
# Data Shape
df.shape
# Out:
# (119390, 33)

# %%
# Length of Data
print(len(df))
# Out:
# 119390

# %%
# Dimension of data
print(df.ndim)
# Out:
# 2

# %%
# Data Datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# we find data type of reservation_status_date is object we need to make it daate type
df['Reservation Date'] = pd.to_datetime(df['reservation_status_date'], errors='coerce')

# %%
# Now its Date Time
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# lets delete null values
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# it seems agent ,reservation_status_date is copy of Reservation Date and company column contaning null values are more and copies
#i dont need that column also iwill drop that columns
df.drop(['agent','company','reservation_status_date'],axis=1,inplace=True)

# %%
# lets check 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.shape
# Out:
# (118898, 30)

# %%
# Lets see statistics of coloumns
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
# We can ADR (average Daily Rate) is seems to be critical lets see it box plot distribution
df['adr'].plot(kind='box')
# Out:
# <Axes: >

# %%
# we can see adr is have values distributed abnormanlly is has a one outlier in it
df=df[df['adr']<5000]

# %%
# Now lets see 
df['adr'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # Data Cleaning Stage is done

# %%
for col in df.describe(include='object').columns:
    print(col)
    print(df[col].unique())
    print('-'*100)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# ----------------------------------------------------------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ----------------------------------------------------------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ----------------------------------------------------------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' 'ROU' 'NOR' 'OMN' 'ARG' 'POL' 'DEU'
#  'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST' 'CZE'
#  'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR' 'UKR'
#  'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO' 'ISR'
#  'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM' 'HRV'
#  'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY' 'KWT'
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'Reservation Date'],
#       dtype='object')

# %%
# Now first see cancellation rate
cancelled_perc=df['is_canceled'].value_counts(normalize=True)
cancelled_perc
# Out:
# is_canceled
# 0    0.628653
# 1    0.371347
# Name: proportion, dtype: float64

# %% [markdown]
# # we can see 62.86% did booking and 37.13% cancelled booking

# %%
plt.title('Reservation - Cancellation')
plt.bar(['Not Cancelled','Cancelled'],(62.86,37.13))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Now lets see which Hotel Cancellation Rate Resort or city hotel
# But for that we have change data type of hotels and is_cancelled coumns
df['hotel'] = df['hotel'].astype(str)
df['is_canceled'] = df['is_canceled'].astype(str)

# %%
# lets see unique data
print(df['hotel'].unique())
print(df['is_canceled'].unique())
# Out:
# ['Resort Hotel' 'City Hotel']
# ['0' '1']

# %%
# lets see count plot of hotels 
ax=sns.countplot(x='hotel',data=df,hue='is_canceled')
for bars in ax.containers:
    ax.bar_label(bars)
plt.xlabel('Hotel')
plt.ylabel('Number of Reservations')
plt.legend(['Not Canceled','Canceled'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # We can clearly see Resort Hotels have less no booking comparitively City Hotels
# # City hotels also have booking cancellation rate also High

# %%
# Now lest see invidual cancelleation rate Resort 
resort_hotel=df[df['hotel']=='Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.72025
# 1    0.27975
# Name: proportion, dtype: float64

# %% [markdown]
# # Resort Hotel 72% booking and 28% cancellation

# %%
# City Hotel
city_hotel=df[df['hotel']=='City Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.582918
# 1    0.417082
# Name: proportion, dtype: float64

# %% [markdown]
# # City Hotel 58% booking and 42% cancellation

# %%
# Lets ADR vs Hotel Wise Reservation

# %% [markdown]
# # ADR vs Reservation of Hotels

# %% [markdown]
# # Resort Hotel

# %%
# Resort Hotel
plt.figure(figsize=(30, 12))
resort_hotel=resort_hotel.groupby('Reservation Date')[['adr']].mean()
resort_hotel_filter = (resort_hotel.index > '2016') & (resort_hotel.index < '2017-09')
resort_hotel_filtered = resort_hotel[resort_hotel_filter].reset_index()
plt.plot(resort_hotel_filtered['Reservation Date'], resort_hotel_filtered['adr'], label='Resort Hotel')
plt.legend(fontsize=25)
plt.xlabel('Reservation Status Date',fontsize=20)
plt.ylabel('Average Daily Rate',fontsize=20)
plt.show()

# %% [markdown]
# # City Hotel

# %%
# City Hotel
plt.figure(figsize=(30, 12))
city_hotel=city_hotel.groupby('Reservation Date')[['adr']].mean()
city_hotel_filter = (city_hotel.index > '2016') & (city_hotel.index < '2017-09')
city_hotel_filtered = city_hotel[city_hotel_filter].reset_index()
plt.plot(city_hotel_filtered['Reservation Date'], city_hotel_filtered['adr'], label='City Hotel')
plt.legend(fontsize=25)
plt.xlabel('Reservation Status Date',fontsize=20)
plt.ylabel('Average Daily Rate',fontsize=20)
plt.show()

# %%
# Lets Combine Hotel vs City
plt.figure(figsize=(35, 16))
resort_hotel=resort_hotel.groupby('Reservation Date')[['adr']].mean()
city_hotel=city_hotel.groupby('Reservation Date')[['adr']].mean()
resort_hotel_filter = (resort_hotel.index > '2016') & (resort_hotel.index < '2017-09')
city_hotel_filter = (city_hotel.index > '2016') & (city_hotel.index < '2017-09')
resort_hotel_filtered = resort_hotel[resort_hotel_filter].reset_index()
city_hotel_filtered = city_hotel[city_hotel_filter].reset_index()
plt.plot(resort_hotel_filtered['Reservation Date'], resort_hotel_filtered['adr'], label='Resort Hotel')
plt.plot(city_hotel_filtered['Reservation Date'], city_hotel_filtered['adr'], label='City Hotel')
plt.legend(fontsize=25)
plt.xlabel('Reservation Status Date',fontsize=20)
plt.ylabel('Average Daily Rate',fontsize=20)
plt.show()

# %% [markdown]
# # Now Lets see month wise cancelation

# %%
df['month']=df['Reservation Date'].dt.month
plt.figure(figsize=(16,8))
ax1=sns.countplot(x='month',hue='is_canceled',data=df,palette='bright')
for bars in ax1.containers:
    ax1.bar_label(bars)
plt.xlabel('month')
plt.ylabel('number of reservation')
plt.title('Month wise Booking Status',size=20)
plt.legend(['not canceled','canceled'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Now we will ADR wise months

# %%
df['is_canceled'] = df['is_canceled'].astype(int)
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15, 8))
plt.title('ADR per Month', fontsize=30)
sns.barplot(x='month', y='adr', data=df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index())
plt.show()

# %% [markdown]
# # Lets see top 10 Country cancellation rate

# %%
# creating data
cancelled_data=df[df['is_canceled']==1]
top_10_country=cancelled_data['country'].value_counts()[:10]
plt.figure(figsize=(8,8))
plt.pie(top_10_country, autopct='%0.2f',labels=top_10_country.index)
plt.title('Top 10 Countries with Cancellation rate')
plt.show()

# %% [markdown]
# # we found Portugal Countries have highest cancelleation rate
# # Do actions on Portugal hotels such take looks on rates, advertisements,facilities,promotions

# %% [markdown]
# # Clients-Travell agents scenarios onLineA,offLineA with cancellations

# %%
#Market segment Counts Bookings coming from
df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: count, dtype: int64

# %%
# Market Segment Percentage of Booking Coming from
df['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: proportion, dtype: float64

# %%
# Market Segement with  cancellation booking
cancelled_data['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: proportion, dtype: float64

# %% [markdown]
# # Online booking cancellations rates are also high coming means according to there facilities when customer go there and see nothing which is seen at the time of booking

# %% [markdown]
# # Cancelletion and Reservation with respect to ADR

# %%
# For cancelled
cancelled_df_adr = cancelled_data.groupby('Reservation Date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values('Reservation Date',inplace=True)

plt.figure(figsize=(30,15))
plt.plot(cancelled_df_adr['Reservation Date'],cancelled_df_adr['adr'],label='cancel')
plt.show()

# %%
# For Not Cancelled
not_cancelled_data=df[df['is_canceled']==0]
not_cancelled_df_adr = not_cancelled_data.groupby('Reservation Date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values('Reservation Date',inplace=True)

plt.figure(figsize=(30,15))
plt.plot(not_cancelled_df_adr['Reservation Date'],not_cancelled_df_adr['adr'],label='not cancel')
plt.show()

# %%
# lets combined cancelled with not cancelled
 
plt.figure(figsize=(30, 15))
plt.title('ADR To Cancelled & Not Cancelled',fontsize=20)

# Filter data based on conditions
cancelled_filter = (cancelled_df_adr['Reservation Date'] > '2016') & (cancelled_df_adr['Reservation Date'] < '2017-09')
not_cancelled_filter = (not_cancelled_df_adr['Reservation Date'] > '2016') & (not_cancelled_df_adr['Reservation Date'] < '2017-09')

# Plot filtered data
plt.plot(cancelled_df_adr.loc[cancelled_filter, 'Reservation Date'], cancelled_df_adr.loc[cancelled_filter, 'adr'], label='cancel')
plt.plot(not_cancelled_df_adr.loc[not_cancelled_filter, 'Reservation Date'], not_cancelled_df_adr.loc[not_cancelled_filter, 'adr'], label='not cancel')

plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# # We found price affecting on cancelletion of hotels
# # we see more cancelletion to ADR when high

# %% [markdown]
# # Conclusion

# %% [markdown]
# We can see 62.86% did booking and 37.13% cancelled booking.
#
# We can clearly see Resort Hotels have less no booking comparitively City Hotels.
#
# City hotels also have booking cancellation rate also High.
#
# Resort Hotel 72% booking and 28% cancellation.
#
# City Hotel 58% booking and 42% cancellation.
#
# We found Portugal Countries have highest cancelleation rate.
#
# Do actions on Portugal hotels such take looks on rates, advertisements,facilities,promotions.
#
# We found price affecting on cancelletion of hotels.
#
# We see more cancelletion to ADR when high.
#
#
# Thank You
# Parag Fartode
